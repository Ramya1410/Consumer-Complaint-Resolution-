# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramya1410/Consumer-Complaint-Resolution-/blob/main/ConsumerComplaintResolutionAnalysisUsing_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Read the Data from the Given excel file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
traindata = pd.read_csv("Consumer_Complaints_train.csv")

# %%
testdata = pd.read_csv("Consumer_Complaints_test.csv")

# %% [markdown]
# Check the data type for both data (test file and train file)

# %%
traindata.dtypes
# Out:
# Date received                    object
# Product                          object
# Sub-product                      object
# Issue                            object
# Sub-issue                        object
# Consumer complaint narrative     object
# Company public response          object
# Company                          object
# State                            object
# ZIP code                         object
# Tags                             object
# Consumer consent provided?       object
# Submitted via                    object
# Date sent to company             object
# Company response to consumer     object
# Timely response?                 object
# Consumer disputed?               object
# Complaint ID                    float64
# dtype: object

# %%
testdata.dtypes
# Out:
# Date received                    object
# Product                          object
# Sub-product                      object
# Issue                            object
# Sub-issue                        object
# Consumer complaint narrative     object
# Company public response          object
# Company                          object
# State                            object
# ZIP code                         object
# Tags                             object
# Consumer consent provided?       object
# Submitted via                    object
# Date sent to company             object
# Company response to consumer     object
# Timely response?                 object
# Complaint ID                    float64
# dtype: object

# %%
traindata.head()
# Out:
#   Date received                  Product  \
# 0    2015-10-14         Credit reporting
# 1    2015-04-26  Bank account or service
# 2    2013-12-20              Credit card
# 3    2016-03-03          Debt collection
# 4    2015-01-30          Debt collection
#
#                              Sub-product  \
# 0                                    NaN
# 1             Other bank product/service
# 2                                    NaN
# 3  Other (i.e. phone, health club, etc.)
# 4                                Medical
#
#                                     Issue  \
# 0  Incorrect information on credit report
# 1                Deposits and withdrawals
# 2                                   Other
# 3         Disclosure verification of debt
# 4         Disclosure verification of debt
#
#                               Sub-issue  \
# 0               Information is not mine
# 1                                   NaN
# 2                                   NaN
# ...

# %%
testdata.head()
# Out:
#   Date received          Product                            Sub-product  \
# 0    2015-01-17      Credit card                                    NaN
# 1    2016-06-22    Consumer Loan                             Title loan
# 2    2015-09-04      Credit card                                    NaN
# 3    2016-05-17    Consumer Loan                       Installment loan
# 4    2016-07-07  Debt collection  Other (i.e. phone, health club, etc.)
#
#                                    Issue  \
# 0  Customer service / Customer relations
# 1           Payment to acct not credited
# 2          Credit line increase/decrease
# 3    Problems when you are unable to pay
# 4    Improper contact or sharing of info
#
#                                Sub-issue  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4  Contacted employer after asked not to
#
# ...

# %%
traindata.isnull()
# Out:
#       Date received  Product  Sub-product  Issue  Sub-issue  \
# 0             False    False         True  False      False
# 1             False    False        False  False       True
# 2             False    False         True  False       True
# 3             False    False        False  False      False
# 4             False    False        False  False      False
# ...             ...      ...          ...    ...        ...
# 2729          False    False        False  False       True
# 2730          False    False        False  False       True
# 2731          False    False        False  False       True
# 2732          False    False        False  False       True
# 2733          False    False         True  False      False
#
#       Consumer complaint narrative  Company public response  Company  State  \
# 0                             True                     True    False  False
# 1                            False                     True    False  False
# ...

# %% [markdown]
# Do missing value analysis and dropcolumns where more than 25% of data are missing

# %%
traindata.isnull().sum()
# Out:
# Date received                      0
# Product                            0
# Sub-product                      794
# Issue                              0
# Sub-issue                       1650
# Consumer complaint narrative    2274
# Company public response         2190
# Company                            0
# State                             22
# ZIP code                          22
# Tags                            2364
# Consumer consent provided?      1929
# Submitted via                      0
# Date sent to company               0
# Company response to consumer       0
# Timely response?                   1
# Consumer disputed?                 1
# Complaint ID                       1
# dtype: int64

# %%
0.25*180668
# Out:
# 45167.0

# %% [markdown]
# we can see that there are 6 columns that have more than 25% missing values. hence, we will drop them.

# %%
traindata = traindata.drop(['Sub-product','Sub-issue','Consumer complaint narrative','Company public response','Tags','Consumer consent provided?'],axis =1)

# %%
traindata.isnull().sum()
# Out:
# Date received                    0
# Product                          0
# Issue                            0
# Company                          0
# State                           22
# ZIP code                        22
# Submitted via                    0
# Date sent to company             0
# Company response to consumer     0
# Timely response?                 1
# Consumer disputed?               1
# Complaint ID                     1
# dtype: int64

# %%
traindata.head()
# Out:
#   Date received                  Product  \
# 0    2015-10-14         Credit reporting
# 1    2015-04-26  Bank account or service
# 2    2013-12-20              Credit card
# 3    2016-03-03          Debt collection
# 4    2015-01-30          Debt collection
#
#                                     Issue  \
# 0  Incorrect information on credit report
# 1                Deposits and withdrawals
# 2                                   Other
# 3         Disclosure verification of debt
# 4         Disclosure verification of debt
#
#                                      Company State ZIP code Submitted via  \
# 0                                    Equifax    GA    30134           Web
# 1                      Wells Fargo & Company    GA    319XX           Web
# 2                                   Citibank    SC    29203         Phone
# 3       FAIR COLLECTIONS & OUTSOURCING, INC.    OH    43082      Referral
# 4  HCFS Health Care Financial Services, Inc.    CA    90036           Web
#
# ...

# %%
traindata['State'].fillna(traindata['State'].mode()[0], inplace = True)
traindata['ZIP code'].fillna(traindata['ZIP code'].mode()[0], inplace = True)

# %%
traindata.isnull().sum()
# Out:
# Date received                   0
# Product                         0
# Issue                           0
# Company                         0
# State                           0
# ZIP code                        0
# Submitted via                   0
# Date sent to company            0
# Company response to consumer    0
# Timely response?                1
# Consumer disputed?              1
# Complaint ID                    1
# dtype: int64

# %%
traindata['Product'].fillna(traindata['Product'].mode()[0], inplace = True)
traindata['Issue'].fillna(traindata['Issue'].mode()[0], inplace = True)
traindata['Company'].fillna(traindata['Company'].mode()[0], inplace = True)
traindata['Submitted via'].fillna(traindata['Submitted via'].mode()[0], inplace = True)
traindata['Date sent to company'].fillna(traindata['Date sent to company'].mode()[0], inplace = True)
traindata['Company response to consumer'].fillna(traindata['Company response to consumer'].mode()[0], inplace = True)
traindata['Timely response?'].fillna(traindata['Timely response?'].mode()[0], inplace = True)
traindata['Consumer disputed?'].fillna(traindata['Consumer disputed?'].mode()[0], inplace = True)
traindata['Complaint ID'].fillna(traindata['Complaint ID'].mode()[0], inplace = True)

# %%
traindata.isnull().sum()
# Out:
# Date received                   0
# Product                         0
# Issue                           0
# Company                         0
# State                           0
# ZIP code                        0
# Submitted via                   0
# Date sent to company            0
# Company response to consumer    0
# Timely response?                0
# Consumer disputed?              0
# Complaint ID                    0
# dtype: int64

# %%
traindata
# Out:
#      Date received                  Product  \
# 0       2015-10-14         Credit reporting
# 1       2015-04-26  Bank account or service
# 2       2013-12-20              Credit card
# 3       2016-03-03          Debt collection
# 4       2015-01-30          Debt collection
# ...            ...                      ...
# 2729    2016-02-25                 Mortgage
# 2730    2016-06-06  Bank account or service
# 2731    2013-03-21                 Mortgage
# 2732    2013-09-26                 Mortgage
# 2733    2015-03-01         Credit reporting
#
#                                          Issue  \
# 0       Incorrect information on credit report
# 1                     Deposits and withdrawals
# 2                                        Other
# 3              Disclosure verification of debt
# 4              Disclosure verification of debt
# ...                                        ...
# 2729  Loan servicing, payments, escrow account
# ...

# %% [markdown]
# Let us repeat that for test data as well.

# %%
testdata
# Out:
#      Date received           Product                            Sub-product  \
# 0       2015-01-17       Credit card                                    NaN
# 1       2016-06-22     Consumer Loan                             Title loan
# 2       2015-09-04       Credit card                                    NaN
# 3       2016-05-17     Consumer Loan                       Installment loan
# 4       2016-07-07   Debt collection  Other (i.e. phone, health club, etc.)
# ...            ...               ...                                    ...
# 2945    2013-11-26   Debt collection  Other (i.e. phone, health club, etc.)
# 2946    2014-02-27  Credit reporting                                    NaN
# 2947    2014-02-27     Consumer Loan                       Installment loan
# 2948    2014-06-02          Mortgage                           FHA mortgage
# 2949    2014-04-18   Debt collection                                Medical
#
#                                          Issue  \
# ...

# %%
0.25*119606
# Out:
# 29901.5

# %%
testdata.isnull().sum()
# Out:
# Date received                      0
# Product                            0
# Sub-product                      815
# Issue                              0
# Sub-issue                       1837
# Consumer complaint narrative    2505
# Company public response         2384
# Company                            0
# State                             21
# ZIP code                          21
# Tags                            2534
# Consumer consent provided?      2115
# Submitted via                      0
# Date sent to company               0
# Company response to consumer       0
# Timely response?                   1
# Complaint ID                       1
# dtype: int64

# %% [markdown]
# Here also, we will be removing 6 columns.

# %%
testdata = testdata.drop(['Sub-product','Sub-issue','Consumer complaint narrative','Company public response','Tags','Consumer consent provided?'],axis = 1)

# %%
testdata.isnull().sum()
# Out:
# Date received                    0
# Product                          0
# Issue                            0
# Company                          0
# State                           21
# ZIP code                        21
# Submitted via                    0
# Date sent to company             0
# Company response to consumer     0
# Timely response?                 1
# Complaint ID                     1
# dtype: int64

# %%
testdata['State'].fillna(testdata['State'].mode()[0],inplace = True)
testdata['ZIP code'].fillna(testdata['ZIP code'].mode()[0],inplace = True)

# %%
testdata.isnull().sum()
# Out:
# Date received                   0
# Product                         0
# Issue                           0
# Company                         0
# State                           0
# ZIP code                        0
# Submitted via                   0
# Date sent to company            0
# Company response to consumer    0
# Timely response?                1
# Complaint ID                    1
# dtype: int64

# %%
testdata
# Out:
#      Date received           Product  \
# 0       2015-01-17       Credit card
# 1       2016-06-22     Consumer Loan
# 2       2015-09-04       Credit card
# 3       2016-05-17     Consumer Loan
# 4       2016-07-07   Debt collection
# ...            ...               ...
# 2945    2013-11-26   Debt collection
# 2946    2014-02-27  Credit reporting
# 2947    2014-02-27     Consumer Loan
# 2948    2014-06-02          Mortgage
# 2949    2014-04-18   Debt collection
#
#                                          Issue  \
# 0        Customer service / Customer relations
# 1                 Payment to acct not credited
# 2                Credit line increase/decrease
# 3          Problems when you are unable to pay
# 4          Improper contact or sharing of info
# ...                                        ...
# 2945                     Communication tactics
# 2946  Credit reporting company's investigation
# 2947       Problems when you are unable to pay
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2734 entries, 0 to 2733
# Data columns (total 12 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date received                 2734 non-null   object
#  1   Product                       2734 non-null   object
#  2   Issue                         2734 non-null   object
#  3   Company                       2734 non-null   object
#  4   State                         2734 non-null   object
#  5   ZIP code                      2734 non-null   object
#  6   Submitted via                 2734 non-null   object
#  7   Date sent to company          2734 non-null   object
#  8   Company response to consumer  2734 non-null   object
#  9   Timely response?              2734 non-null   object
#  10  Consumer disputed?            2734 non-null   object
#  11  Complaint ID                  2734 non-null   float64
# dtypes: float64(1), object(11)
# ...

# %%
testdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2950 entries, 0 to 2949
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date received                 2950 non-null   object
#  1   Product                       2950 non-null   object
#  2   Issue                         2950 non-null   object
#  3   Company                       2950 non-null   object
#  4   State                         2950 non-null   object
#  5   ZIP code                      2950 non-null   object
#  6   Submitted via                 2950 non-null   object
#  7   Date sent to company          2950 non-null   object
#  8   Company response to consumer  2950 non-null   object
#  9   Timely response?              2949 non-null   object
#  10  Complaint ID                  2949 non-null   float64
# dtypes: float64(1), object(10)
# memory usage: 253.6+ KB

# %% [markdown]
# Extracting Day, Month,and Year from Date Received Column and create new fields for a month, year,and day

# %%
traindata['year'] = pd.DatetimeIndex(traindata['Date received']).year
traindata['month'] = pd.DatetimeIndex(traindata['Date received']).month
traindata['day'] = pd.DatetimeIndex(traindata['Date received']).day

# %%
traindata.head()
# Out:
#   Date received                  Product  \
# 0    2015-10-14         Credit reporting
# 1    2015-04-26  Bank account or service
# 2    2013-12-20              Credit card
# 3    2016-03-03          Debt collection
# 4    2015-01-30          Debt collection
#
#                                     Issue  \
# 0  Incorrect information on credit report
# 1                Deposits and withdrawals
# 2                                   Other
# 3         Disclosure verification of debt
# 4         Disclosure verification of debt
#
#                                      Company State ZIP code Submitted via  \
# 0                                    Equifax    GA    30134           Web
# 1                      Wells Fargo & Company    GA    319XX           Web
# 2                                   Citibank    SC    29203         Phone
# 3       FAIR COLLECTIONS & OUTSOURCING, INC.    OH    43082      Referral
# 4  HCFS Health Care Financial Services, Inc.    CA    90036           Web
#
# ...

# %%
testdata['year'] = pd.DatetimeIndex(testdata['Date received']).year
testdata['month'] = pd.DatetimeIndex(testdata['Date received']).month
testdata['day'] = pd.DatetimeIndex(testdata['Date received']).day

# %%
testdata.head()
# Out:
#   Date received          Product                                  Issue  \
# 0    2015-01-17      Credit card  Customer service / Customer relations
# 1    2016-06-22    Consumer Loan           Payment to acct not credited
# 2    2015-09-04      Credit card          Credit line increase/decrease
# 3    2016-05-17    Consumer Loan    Problems when you are unable to pay
# 4    2016-07-07  Debt collection    Improper contact or sharing of info
#
#                             Company State ZIP code Submitted via  \
# 0                          Citibank    TX    75241           Web
# 1  Larsen MacColl Partners II, L.P.    TX    76548         Phone
# 2                       Capital One    NC    271XX           Web
# 3   OneMain Financial Holdings, LLC    MO    634XX           Web
# 4              GMA Investments, LLC    SC    296XX           Web
#
#   Date sent to company     Company response to consumer Timely response?  \
# ...

# %% [markdown]
# Calculatethe Number ofDays the Complaint was with the Companyand create a new field as “Days held”

# %%
import datetime as dt

# %%
traindata[['Date received','Date sent to company']] = traindata[['Date received','Date sent to company']].apply(pd.to_datetime) #if conversion required
traindata['Days Held'] = (traindata['Date sent to company'] - traindata['Date received']).dt.days

# %%
traindata
# Out:
#      Date received                  Product  \
# 0       2015-10-14         Credit reporting
# 1       2015-04-26  Bank account or service
# 2       2013-12-20              Credit card
# 3       2016-03-03          Debt collection
# 4       2015-01-30          Debt collection
# ...            ...                      ...
# 2729    2016-02-25                 Mortgage
# 2730    2016-06-06  Bank account or service
# 2731    2013-03-21                 Mortgage
# 2732    2013-09-26                 Mortgage
# 2733    2015-03-01         Credit reporting
#
#                                          Issue  \
# 0       Incorrect information on credit report
# 1                     Deposits and withdrawals
# 2                                        Other
# 3              Disclosure verification of debt
# 4              Disclosure verification of debt
# ...                                        ...
# 2729  Loan servicing, payments, escrow account
# ...

# %%
testdata[['Date received','Date sent to company']] = testdata[['Date received','Date sent to company']].apply(pd.to_datetime) #if conversion required
testdata['Days Held'] = (testdata['Date sent to company'] - testdata['Date received']).dt.days

# %%
testdata
# Out:
#      Date received           Product  \
# 0       2015-01-17       Credit card
# 1       2016-06-22     Consumer Loan
# 2       2015-09-04       Credit card
# 3       2016-05-17     Consumer Loan
# 4       2016-07-07   Debt collection
# ...            ...               ...
# 2945    2013-11-26   Debt collection
# 2946    2014-02-27  Credit reporting
# 2947    2014-02-27     Consumer Loan
# 2948    2014-06-02          Mortgage
# 2949    2014-04-18   Debt collection
#
#                                          Issue  \
# 0        Customer service / Customer relations
# 1                 Payment to acct not credited
# 2                Credit line increase/decrease
# 3          Problems when you are unable to pay
# 4          Improper contact or sharing of info
# ...                                        ...
# 2945                     Communication tactics
# 2946  Credit reporting company's investigation
# 2947       Problems when you are unable to pay
# ...

# %% [markdown]
# with the help ofthe days we calculated above,create a newfield 'Week_Received'where we calculate the week based on the day of receiving

# %%
traindata['Week_Received'] = traindata['Date received'].dt.week
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %%
traindata.head()
# Out:
#   Date received                  Product  \
# 0    2015-10-14         Credit reporting
# 1    2015-04-26  Bank account or service
# 2    2013-12-20              Credit card
# 3    2016-03-03          Debt collection
# 4    2015-01-30          Debt collection
#
#                                     Issue  \
# 0  Incorrect information on credit report
# 1                Deposits and withdrawals
# 2                                   Other
# 3         Disclosure verification of debt
# 4         Disclosure verification of debt
#
#                                      Company State ZIP code Submitted via  \
# 0                                    Equifax    GA    30134           Web
# 1                      Wells Fargo & Company    GA    319XX           Web
# 2                                   Citibank    SC    29203         Phone
# 3       FAIR COLLECTIONS & OUTSOURCING, INC.    OH    43082      Referral
# 4  HCFS Health Care Financial Services, Inc.    CA    90036           Web
#
# ...

# %%
testdata['Week_Received'] = testdata['Date received'].dt.week
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Drop "Date Received","Date Sent to Company","ZIP Code", "Complaint ID"fields•Imputing Nullvalue in “State”by Mode

# %%
traindata = traindata.drop(['Date received','Date sent to company','ZIP code','Complaint ID'],axis=1)

# %%
traindata.head()
# Out:
#                    Product                                   Issue  \
# 0         Credit reporting  Incorrect information on credit report
# 1  Bank account or service                Deposits and withdrawals
# 2              Credit card                                   Other
# 3          Debt collection         Disclosure verification of debt
# 4          Debt collection         Disclosure verification of debt
#
#                                      Company State Submitted via  \
# 0                                    Equifax    GA           Web
# 1                      Wells Fargo & Company    GA           Web
# 2                                   Citibank    SC         Phone
# 3       FAIR COLLECTIONS & OUTSOURCING, INC.    OH      Referral
# 4  HCFS Health Care Financial Services, Inc.    CA           Web
#
#       Company response to consumer Timely response? Consumer disputed?  year  \
# 0          Closed with explanation              Yes                 No  2015
# ...

# %%
testdata = testdata.drop(['Date received','Date sent to company','ZIP code','Complaint ID'],axis=1)

# %%
testdata.head()
# Out:
#            Product                                  Issue  \
# 0      Credit card  Customer service / Customer relations
# 1    Consumer Loan           Payment to acct not credited
# 2      Credit card          Credit line increase/decrease
# 3    Consumer Loan    Problems when you are unable to pay
# 4  Debt collection    Improper contact or sharing of info
#
#                             Company State Submitted via  \
# 0                          Citibank    TX           Web
# 1  Larsen MacColl Partners II, L.P.    TX         Phone
# 2                       Capital One    NC           Web
# 3   OneMain Financial Holdings, LLC    MO           Web
# 4              GMA Investments, LLC    SC           Web
#
#       Company response to consumer Timely response?  year  month  day  \
# 0      Closed with monetary relief              Yes  2015      1   17
# 1          Closed with explanation              Yes  2016      6   22
# ...

# %%
traindata.isnull().sum()
# Out:
# Product                         0
# Issue                           0
# Company                         0
# State                           0
# Submitted via                   0
# Company response to consumer    0
# Timely response?                0
# Consumer disputed?              0
# year                            0
# month                           0
# day                             0
# Days Held                       0
# Week_Received                   0
# dtype: int64

# %%
traindata
# Out:
#                       Product                                     Issue  \
# 0            Credit reporting    Incorrect information on credit report
# 1     Bank account or service                  Deposits and withdrawals
# 2                 Credit card                                     Other
# 3             Debt collection           Disclosure verification of debt
# 4             Debt collection           Disclosure verification of debt
# ...                       ...                                       ...
# 2729                 Mortgage  Loan servicing, payments, escrow account
# 2730  Bank account or service  Making/receiving payments, sending money
# 2731                 Mortgage  Loan modification,collection,foreclosure
# 2732                 Mortgage  Loan servicing, payments, escrow account
# 2733         Credit reporting    Incorrect information on credit report
#
#                                         Company State Submitted via  \
# ...

# %%
disputed_cons = traindata['Consumer disputed?'] == 'Yes'
disp = disputed_cons.sum()
disp
# Out:
# 597

# %%
not_disputed_cons = traindata['Consumer disputed?']=='No'
ndisp = not_disputed_cons.sum()
ndisp
# Out:
# 2137

# %% [markdown]
# Plot bar graph of thetotal no of disputes of consumers with the help ofseaborn

# %%
sns.set_style('darkgrid')

xfinal = ['disputed_customers', 'non_disputed_customers']
yfinal = [disp, ndisp]

sns.barplot(xfinal, yfinal)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
traindata['disputed_consumers'] = traindata['Consumer disputed?'].map({'Yes': '1', 'No':'0'})

# %%
traindata.head()
# Out:
#                    Product                                   Issue  \
# 0         Credit reporting  Incorrect information on credit report
# 1  Bank account or service                Deposits and withdrawals
# 2              Credit card                                   Other
# 3          Debt collection         Disclosure verification of debt
# 4          Debt collection         Disclosure verification of debt
#
#                                      Company State Submitted via  \
# 0                                    Equifax    GA           Web
# 1                      Wells Fargo & Company    GA           Web
# 2                                   Citibank    SC         Phone
# 3       FAIR COLLECTIONS & OUTSOURCING, INC.    OH      Referral
# 4  HCFS Health Care Financial Services, Inc.    CA           Web
#
#       Company response to consumer Timely response? Consumer disputed?  year  \
# 0          Closed with explanation              Yes                 No  2015
# ...

# %%
traindata.dtypes
# Out:
# Product                         object
# Issue                           object
# Company                         object
# State                           object
# Submitted via                   object
# Company response to consumer    object
# Timely response?                object
# Consumer disputed?              object
# year                             int64
# month                            int64
# day                              int64
# Days Held                        int64
# Week_Received                    int64
# disputed_consumers              object
# dtype: object

# %%
traindata['disputed_consumers'] = pd.to_numeric(traindata['disputed_consumers'])

# %%
traindata.dtypes
# Out:
# Product                         object
# Issue                           object
# Company                         object
# State                           object
# Submitted via                   object
# Company response to consumer    object
# Timely response?                object
# Consumer disputed?              object
# year                             int64
# month                            int64
# day                              int64
# Days Held                        int64
# Week_Received                    int64
# disputed_consumers               int64
# dtype: object

# %%
print(traindata.groupby(["Product"])["disputed_consumers"].sum().rename('disputed_consumers_sum').reset_index())
# Out:
#                     Product  disputed_consumers_sum
# 0   Bank account or service                      56
# 1             Consumer Loan                      28
# 2               Credit card                      77
# 3          Credit reporting                      83
# 4           Debt collection                     112
# 5           Money transfers                       4
# 6                  Mortgage                     214
# 7   Other financial service                       1
# 8               Payday loan                       2
# 9              Prepaid card                       1
# 10             Student loan                      19

# %%
product = pd.DataFrame(traindata.groupby(["Product"])["disputed_consumers"].sum().rename('disputed_consumers_sum').reset_index())

# %%
product
# Out:
#                     Product  disputed_consumers_sum
# 0   Bank account or service                      56
# 1             Consumer Loan                      28
# 2               Credit card                      77
# 3          Credit reporting                      83
# 4           Debt collection                     112
# 5           Money transfers                       4
# 6                  Mortgage                     214
# 7   Other financial service                       1
# 8               Payday loan                       2
# 9              Prepaid card                       1
# 10             Student loan                      19

# %% [markdown]
# Plot bar graph of thetotal no of disputes products-wise with the help ofseaborn

# %%
sns.barplot(x = 'disputed_consumers_sum' ,y = 'Product', data = product)

# %%
Issue = pd.DataFrame(traindata.groupby(["Issue"])["disputed_consumers"].sum().rename('Issue_sum').reset_index())

# %%
Issue
# Out:
#                                        Issue  Issue_sum
# 0                       APR or interest rate          9
# 1    Account opening, closing, or management         21
# 2                  Account terms and changes          0
# 3                               Adding money          0
# 4                  Advertising and marketing          3
# ..                                       ...        ...
# 74  Unable to get credit report/credit score          7
# 75   Unauthorized transactions/trans. issues          1
# 76       Unsolicited issuance of credit card          1
# 77                 Using a debit or ATM card          7
# 78          Wrong amount charged or received          0
#
# [79 rows x 2 columns]

# %%
Issue = Issue.sort_values(by=['Issue_sum'])
Issue.tail(10)
# Out:
#                                        Issue  Issue_sum
# 22                     Communication tactics         13
# 30  Credit reporting company's investigation         15
# 35                  Deposits and withdrawals         16
# 12                          Billing disputes         16
# 1    Account opening, closing, or management         21
# 36           Disclosure verification of debt         36
# 23     Cont'd attempts collect debt not owed         40
# 44    Incorrect information on credit report         58
# 47  Loan servicing, payments, escrow account         67
# 46  Loan modification,collection,foreclosure        114

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Issue_sum' ,y = 'Issue', data=Issue.nlargest(10, 'Issue_sum'))
plt.show()

# %% [markdown]
# Plot bar graph ofthe total no of disputes by State with Maximum Disputes

# %%
state = pd.DataFrame(traindata.groupby(["State"])["disputed_consumers"].sum().rename('State_sum').reset_index())

# %%
state
# Out:
#    State  State_sum
# 0     AK          1
# 1     AL         10
# 2     AR          0
# 3     AZ         11
# 4     CA         95
# 5     CO         14
# 6     CT          9
# 7     DC          2
# 8     DE          2
# 9     FL         63
# 10    FM          0
# 11    GA         27
# 12    HI          2
# 13    IA          3
# 14    ID          1
# 15    IL         28
# 16    IN          7
# 17    KS          3
# 18    KY          7
# 19    LA          7
# 20    MA          8
# 21    MD         22
# 22    ME          4
# 23    MI          8
# 24    MN          6
# 25    MO          5
# 26    MS          2
# 27    MT          1
# 28    NC         15
# 29    ND          2
# 30    NE          1
# 31    NH          2
# 32    NJ         31
# 33    NM          2
# 34    NV          7
# 35    NY         22
# 36    OH         20
# 37    OK          5
# 38    OR          7
# 39    PA         19
# 40    PR          0
# 41    RI          3
# 42    SC          2
# 43    SD          0
# ...

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'State_sum' ,y = 'State', data=state.nlargest(10, 'State_sum'))
plt.show()

# %% [markdown]
# Plotbar graph ofthe total no of disputes Submitted Via differentsource

# %%
source = pd.DataFrame(traindata.groupby(["Submitted via"])["disputed_consumers"].sum().rename('source_sum').reset_index())

# %%
source
# Out:
#   Submitted via  source_sum
# 0           Fax           5
# 1         Phone          31
# 2   Postal mail          32
# 3      Referral         102
# 4           Web         427

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'source_sum' ,y = 'Submitted via', data=source)
plt.show()

# %% [markdown]
# Plot bar graph ofthe total no of disputes where the Company's Response to the Complaints

# %%
response = pd.DataFrame(traindata.groupby(["Company response to consumer"])["disputed_consumers"].sum().rename('response_sum').reset_index())

# %%
response
# Out:
#       Company response to consumer  response_sum
# 0                           Closed            18
# 1                Closed with expla             0
# 2          Closed with explanation           491
# 3      Closed with monetary relief            27
# 4  Closed with non-monetary relief            41
# 5               Closed with relief             6
# 6            Closed without relief            14

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'response_sum' ,y = 'Company response to consumer', data=response)
plt.show()

# %% [markdown]
# Plot bar graph ofthe total no of disputes.Whether there are Disputes Instead of Timely Response

# %%
timely = pd.DataFrame(traindata.groupby(["Timely response?"])["disputed_consumers"].sum().rename('timely_sum').reset_index())

# %%
timely
# Out:
#   Timely response?  timely_sum
# 0               No           9
# 1              Yes         588

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'timely_sum' ,y = 'Timely response?', data=timely)
plt.show()

# %% [markdown]
# Plot bar graph ofthe total no of disputes over Year Wise Complaints

# %%
yearly = pd.DataFrame(traindata.groupby(["year"])["disputed_consumers"].sum().rename('yearly_sum').reset_index())

# %%
yearly
# Out:
#    year  yearly_sum
# 0  2011           4
# 1  2012          70
# 2  2013         116
# 3  2014         136
# 4  2015         161
# 5  2016         110

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'year' , y = 'yearly_sum', data = yearly)
plt.show()

# %%
traindata
# Out:
#                       Product                                     Issue  \
# 0            Credit reporting    Incorrect information on credit report
# 1     Bank account or service                  Deposits and withdrawals
# 2                 Credit card                                     Other
# 3             Debt collection           Disclosure verification of debt
# 4             Debt collection           Disclosure verification of debt
# ...                       ...                                       ...
# 2729                 Mortgage  Loan servicing, payments, escrow account
# 2730  Bank account or service  Making/receiving payments, sending money
# 2731                 Mortgage  Loan modification,collection,foreclosure
# 2732                 Mortgage  Loan servicing, payments, escrow account
# 2733         Credit reporting    Incorrect information on credit report
#
#                                         Company State Submitted via  \
# ...

# %% [markdown]
# Converte all negative days held to zero(it is the time taken by the authority that can't be negative)

# %%
traindata[traindata['day'] < 0] = 0

# %%
traindata = traindata.drop(['Company', 'State', 'year', 'Days Held'], axis = 1)

# %%
traindata.head()
# Out:
#                    Product                                   Issue  \
# 0         Credit reporting  Incorrect information on credit report
# 1  Bank account or service                Deposits and withdrawals
# 2              Credit card                                   Other
# 3          Debt collection         Disclosure verification of debt
# 4          Debt collection         Disclosure verification of debt
#
#   Submitted via     Company response to consumer Timely response?  \
# 0           Web          Closed with explanation              Yes
# 1           Web          Closed with explanation              Yes
# 2         Phone  Closed with non-monetary relief              Yes
# 3      Referral          Closed with explanation              Yes
# 4           Web          Closed with explanation              Yes
#
#   Consumer disputed?  month  day  Week_Received  disputed_consumers
# 0                 No     10   14             42                   0
# ...

# %%
pd.concat([traindata,pd.get_dummies(traindata, columns=['Product', 'Submitted via', 'Company response to consumer', 'Timely response?'],drop_first=True)],axis=1)
# Out:
#                       Product                                     Issue  \
# 0            Credit reporting    Incorrect information on credit report
# 1     Bank account or service                  Deposits and withdrawals
# 2                 Credit card                                     Other
# 3             Debt collection           Disclosure verification of debt
# 4             Debt collection           Disclosure verification of debt
# ...                       ...                                       ...
# 2729                 Mortgage  Loan servicing, payments, escrow account
# 2730  Bank account or service  Making/receiving payments, sending money
# 2731                 Mortgage  Loan modification,collection,foreclosure
# 2732                 Mortgage  Loan servicing, payments, escrow account
# 2733         Credit reporting    Incorrect information on credit report
#
#      Submitted via     Company response to consumer Timely response?  \
# ...

# %%
x = traindata.drop("Company response to consumer",1)
y = traindata['Company response to consumer']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
traindata['Product'] = le.fit_transform(traindata['Product'])
traindata['Issue'] = le.fit_transform(traindata['Issue'])
traindata['Submitted via'] = le.fit_transform(traindata['Submitted via'])
traindata['Timely response?'] = le.fit_transform(traindata['Timely response?'])
traindata['Consumer disputed?'] = le.fit_transform(traindata['Consumer disputed?'])

# %%
traindata.head()
# Out:
#    Product  Issue  Submitted via     Company response to consumer  \
# 0        3     44              4          Closed with explanation
# 1        0     35              4          Closed with explanation
# 2        2     55              1  Closed with non-monetary relief
# 3        4     36              3          Closed with explanation
# 4        4     36              4          Closed with explanation
#
#    Timely response?  Consumer disputed?  month  day  Week_Received  \
# 0                 1                   0     10   14             42
# 1                 1                   1      4   26             17
# 2                 1                   0     12   20             51
# 3                 1                   0      3    3              9
# 4                 1                   1      1   30              5
#
#    disputed_consumers
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1

# %%
x
# Out:
#       Product  Issue  Submitted via  Timely response?  Consumer disputed?  \
# 0           3     44              4                 1                   0
# 1           0     35              4                 1                   1
# 2           2     55              1                 1                   0
# 3           4     36              3                 1                   0
# 4           4     36              4                 1                   1
# ...       ...    ...            ...               ...                 ...
# 2729        6     47              4                 1                   0
# 2730        0     50              3                 1                   0
# 2731        6     46              3                 1                   0
# 2732        6     47              4                 1                   1
# 2733        3     44              4                 1                   0
#
#       month  day  Week_Received  disputed_consumers
# ...

# %%
x.dtypes
# Out:
# Product               int64
# Issue                 int64
# Submitted via         int64
# Timely response?      int64
# Consumer disputed?    int64
# month                 int64
# day                   int64
# Week_Received         int64
# disputed_consumers    int64
# dtype: object

# %%
x = StandardScaler().fit_transform(x)

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf.head()
# Out:
#    principal component 1  principal component 2
# 0               0.318183              -1.731167
# 1               1.775869               2.073615
# 2               0.650475              -2.766887
# 3              -1.448212               0.811181
# 4               1.142668               3.162331

# %%
pca.explained_variance_ratio_
# Out:
# array([0.22747885, 0.21456421])

# %% [markdown]
# Logistic Regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
xtrain = sc_x.fit_transform(X_train) 
xtest = sc_x.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(xtest)

# %%
from sklearn.metrics import accuracy_score
print ("Accuracy : ", accuracy_score(y_test, y_pred))
# Out:
# Accuracy :  0.7339181286549707

# %% [markdown]
# Decision Tree Classifier

# %%
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size = 0.3, random_state = 100)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
gini_clf = DecisionTreeClassifier(criterion = 'gini', max_depth = 3, random_state = 0)
gini_clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %% [markdown]
# Predict the Test set results with criterion gini index

# %%
y_pred_gini = gini_clf.predict(x_test)

# %% [markdown]
# Check accuracy score with criterion gini index

# %%
from sklearn.metrics import accuracy_score

# %%
print('model accuracy score with criterion gini index: {0:0.4f}'.format(accuracy_score(y_test,y_pred_gini)))
# Out:
# model accuracy score with criterion gini index: 0.7406

# %%
print('Training set score: {:.4f}'.format(gini_clf.score(x_train,y_train)))
print('Testing score: {:.4f}'.format(gini_clf.score(x_test,y_test)))
# Out:
# Training set score: 0.7475
# Testing score: 0.7406

# %% [markdown]
# Random Forest Classifier

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf = RandomForestClassifier(n_estimators = 100)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics 
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.70018281535649

# %% [markdown]
# AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3) # 70% training and 30% test

# %%
abc = AdaBoostClassifier(n_estimators=50, learning_rate=1)

# %%
model = abc.fit(X_train, y_train)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6345919610231425

# %% [markdown]
# Gradient Boosting Classifier

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3) # 70% training and 30% test

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_clf = GradientBoostingClassifier(n_estimators=20, max_features=2, max_depth=2, random_state=0)
gb_clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(max_depth=2, max_features=2, n_estimators=20,
#                            random_state=0)

# %%
print("Accuracy score (training): {0:.3f}".format(gb_clf.score(X_train, y_train)))
# Out:
# Accuracy score (training): 0.752

# %% [markdown]
# KNeighbours Classifier

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
Range_k = range(1,5)

# %%
for k in Range_k:
  classifier = KNeighborsClassifier(n_neighbors=k)
  classifier.fit(X_train, y_train)
  y_pred = classifier.predict(X_test)

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.7259439707673568

# %% [markdown]
# XGB Classifier

# %%
from xgboost import XGBClassifier

# %%
xtrain, xtest, ytrain, ytest=train_test_split(x, y, test_size=0.15)

# %%
xgbc = XGBClassifier()

# %%
XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
       colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
       max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
       n_estimators=100, n_jobs=1, nthread=None,
       objective='multi:softprob', random_state=0, reg_alpha=0,
       reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
       subsample=1, verbosity=1)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
xgbc.fit(xtrain, ytrain)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.7259439707673568

# %% [markdown]
# Therefore, we can conclude that gradient boost classifier gives the best accuracy and Adaboost classifier gives the worst accuracy.
